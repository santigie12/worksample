# %% [markdown]
# ### My explanation is  going inline with the module

# %% [markdown]
# # Problem 1 Create using the exponentiation arithmetic operator

# %%
#By multiplying the thickness of the origernal paper by 2 to the 43rd power, the thickness of 43 diffractions can be obtained.

THICKNESS = 0.00008 #the thickness size
folded_thickness = THICKNESS*2**43    #multiplying the thickness by 2 to the power 
print("Thickness： {} meters".format(folded_thickness))
# Out:
# Thickness： 703687441.77664 meters

# %% [markdown]
# # Problem 2 Unit Conversion

# %%
#convert a meter into a kilometer 
print("Thickness： {:.2f}km".format(folded_thickness/10000))
# Out:
# Thickness： 70368.74km

# %% [markdown]
# Distance to the Moon is 384,400 km But the paper is 70368.74km So the paper did not reach the moon
#
# # Problem 3 Create using a for statement

# %%
#calculating the thickness of all iteration to increase the thickness

def paper(num_folds=43, thickness=0.00008):
    for i in range(1, num_folds + 1): 
        thickness = thickness *2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2
        print("Thickness： {} meters".format(thickness))
        if thickness >= 10000:
            #convert to kilometer
            print("Thickness： {:.2f}km".format(thickness/10000))
        else:
            #convert to meter
           
            print("Thickness： {:.2f}meter".format(thickness/1000))

# %% [markdown]
# # Problem 4 Comparison of calculation time

# %%
import time
                       
start = time.time() 
THICKNESS = 0.00008   #the paper thickness
folded_thickness = THICKNESS*2**43    #multiplying the thickness by 2 to the power 
print("Thickness： {} meters".format(folded_thickness))
elapsed_time = time.time() - start             #calculating the time
print("time : {} sec".format(elapsed_time))
# Out:
# Thickness： 703687441.77664 meters
# time : 0.0 sec

# %%
# %%timeit
folded_thickness = THICKNESS*2**43  #multiplying the thickness by 2 to the power 
folded_thickness
print("Thickness： {} meters".format(folded_thickness))
# Out:
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# Thickness： 703687441.77664 meters
# ...

# %% [markdown]
# # Problem 5 Saving to a list

# %%
#Creating an empty list
list1 = [0.00008]
fold_num = 43
thickness = 0.00008

#folded_thickness = 
for i in range(1, fold_num + 1):
    folded_thickness = thickness*2**i
    
#Add values to the list
    list1.append(folded_thickness)
    print(list1)
    print(len(list1))
# Out:
# [8e-05, 0.00016]
# 2
# [8e-05, 0.00016, 0.00032]
# 3
# [8e-05, 0.00016, 0.00032, 0.00064]
# 4
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128]
# 5
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256]
# 6
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512]
# 7
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024]
# 8
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048]
# 9
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096]
# 10
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192]
# 11
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384]
# 12
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384, 0.32768]
# 13
# ...

# %% [markdown]
# # PROBLEM 6- DISPLAYING A LINE GRAPE

# %%
import matplotlib.pyplot as plt
#%matplotlib inline
#visualizating the thickness of the folded paper

plt.title("thickness of folded paper") #the title
plt.xlabel("number of folds")  #xlabel caption
plt.ylabel("thickness[M]")     #ylabel caption
plt.tick_params(labelsize=10)
plt.plot(list1)
plt.show()

# %% [markdown]
# THE THICKNESS OF THE INCREASES WHEN THE NUMBER OF FOLDS INCREASES.
# # PROBLEM 7- Customizing graphs

# %%
#Making the line dotted
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[M]")
#changing line style and color
plt.plot(list1, 'ro' )

plt.figure(figsize=(48, 20))
plt.show()
